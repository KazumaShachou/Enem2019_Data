# %%
import pandas as pd
import numpy as np

# %%
enem = pd.read_csv('https://raw.githubusercontent.com/alura-cursos/imersao-dados-2-2020/master/MICRODADOS_ENEM_2019_SAMPLE_43278.csv')
enem.head()
# Out:
#    NU_INSCRICAO  NU_ANO  CO_MUNICIPIO_RESIDENCIA  ... Q023  Q024 Q025
# 0  190001004661    2019                  1506138  ...    A     B    B
# 1  190001004674    2019                  1504208  ...    A     A    B
# 2  190001004722    2019                  1501402  ...    A     A    B
# 3  190001004735    2019                  1507300  ...    A     A    B
# 4  190001004776    2019                  1500800  ...    A     A    B
#
# [5 rows x 136 columns]

# %%
enem.describe()
# Out:
#        NU_INSCRICAO    NU_ANO  ...  NU_NOTA_REDACAO           Q005
# count  1.273800e+05  127380.0  ...     98043.000000  127380.000000
# mean   1.900035e+11    2019.0  ...       571.570025       3.864068
# std    1.469535e+06       0.0  ...       188.076455       1.475714
# min    1.900010e+11    2019.0  ...         0.000000       1.000000
# 25%    1.900023e+11    2019.0  ...       480.000000       3.000000
# 50%    1.900035e+11    2019.0  ...       580.000000       4.000000
# 75%    1.900048e+11    2019.0  ...       680.000000       5.000000
# max    1.900061e+11    2019.0  ...      1000.000000      20.000000
#
# [8 rows x 95 columns]

# %%
#describe lines and columns total
enem.shape
# Out:
# (127380, 136)

# %%
#select only 1 column
enem['SG_UF_RESIDENCIA']
# Out:
# 0         PA
# 1         PA
# 2         PA
# 3         PA
# 4         PA
#           ..
# 127375    MG
# 127376    BA
# 127377    BA
# 127378    BA
# 127379    MG
# Name: SG_UF_RESIDENCIA, Length: 127380, dtype: object

# %%
#return wholes columns
enem.columns.values
# Out:
# array(['NU_INSCRICAO', 'NU_ANO', 'CO_MUNICIPIO_RESIDENCIA',
#        'NO_MUNICIPIO_RESIDENCIA', 'CO_UF_RESIDENCIA', 'SG_UF_RESIDENCIA',
#        'NU_IDADE', 'TP_SEXO', 'TP_ESTADO_CIVIL', 'TP_COR_RACA',
#        'TP_NACIONALIDADE', 'CO_MUNICIPIO_NASCIMENTO',
#        'NO_MUNICIPIO_NASCIMENTO', 'CO_UF_NASCIMENTO', 'SG_UF_NASCIMENTO',
#        'TP_ST_CONCLUSAO', 'TP_ANO_CONCLUIU', 'TP_ESCOLA', 'TP_ENSINO',
#        'IN_TREINEIRO', 'CO_ESCOLA', 'CO_MUNICIPIO_ESC',
#        'NO_MUNICIPIO_ESC', 'CO_UF_ESC', 'SG_UF_ESC',
#        'TP_DEPENDENCIA_ADM_ESC', 'TP_LOCALIZACAO_ESC', 'TP_SIT_FUNC_ESC',
#        'IN_BAIXA_VISAO', 'IN_CEGUEIRA', 'IN_SURDEZ',
#        'IN_DEFICIENCIA_AUDITIVA', 'IN_SURDO_CEGUEIRA',
#        'IN_DEFICIENCIA_FISICA', 'IN_DEFICIENCIA_MENTAL',
#        'IN_DEFICIT_ATENCAO', 'IN_DISLEXIA', 'IN_DISCALCULIA',
#        'IN_AUTISMO', 'IN_VISAO_MONOCULAR', 'IN_OUTRA_DEF', 'IN_GESTANTE',
#        'IN_LACTANTE', 'IN_IDOSO', 'IN_ESTUDA_CLASSE_HOSPITALAR',
# ...

# %%
#when I want to select 2 columns, I need to use a list of names of this list , so I need to use [[]]
enem[['SG_UF_RESIDENCIA', 'Q025']]
# Out:
#        SG_UF_RESIDENCIA Q025
# 0                    PA    B
# 1                    PA    B
# 2                    PA    B
# 3                    PA    B
# 4                    PA    B
# ...                 ...  ...
# 127375               MG    B
# 127376               BA    B
# 127377               BA    B
# 127378               BA    A
# 127379               MG    B
#
# [127380 rows x 2 columns]

# %%
#get a columns that have the states of Brazil
enem['SG_UF_RESIDENCIA']
# Out:
# 0         PA
# 1         PA
# 2         PA
# 3         PA
# 4         PA
#           ..
# 127375    MG
# 127376    BA
# 127377    BA
# 127378    BA
# 127379    MG
# Name: SG_UF_RESIDENCIA, Length: 127380, dtype: object

# %%
#whice states in this list (names of abbrev)   - they return a array, cause of numpy

enem['SG_UF_RESIDENCIA'].unique()
# Out:
# array(['PA', 'RO', 'MT', 'AC', 'AM', 'RR', 'MA', 'PR', 'BA', 'PI', 'CE',
#        'PE', 'AP', 'TO', 'SC', 'GO', 'MG', 'SP', 'SE', 'RJ', 'PB', 'AL',
#        'RN', 'ES', 'DF', 'RS', 'MS'], dtype=object)

# %%
#how many states? -  just use len  
len(enem['SG_UF_RESIDENCIA'].unique())
# Out:
# 27

# %%
#count how many elements of each states
enem['SG_UF_RESIDENCIA'].value_counts()
# Out:
# SP    20264
# MG    13547
# BA    10040
# RJ     8467
# CE     7381
# PA     7170
# PE     6941
# MA     5543
# RS     5466
# PR     5259
# GO     4268
# PB     3690
# PI     3034
# RN     2959
# AM     2820
# SC     2673
# ES     2550
# DF     2408
# AL     2263
# MT     2230
# SE     1815
# MS     1655
# RO     1400
# TO     1178
# AP     1047
# AC      946
# RR      366
# Name: SG_UF_RESIDENCIA, dtype: int64

# %%
#now we will see the age of participants  
enem['NU_IDADE'].value_counts().head(10)
# Out:
# 18    21452
# 17    21256
# 19    14418
# 20    10413
# 16     7830
# 21     7267
# 22     5924
# 23     4668
# 24     3838
# 25     3128
# Name: NU_IDADE, dtype: int64

# %%
#if I want to order per age in index, I just need to use sort_index()
enem['NU_IDADE'].value_counts().sort_index()
# Out:
# 13        4
# 14      141
# 15     2009
# 16     7830
# 17    21256
#       ...
# 73        2
# 75        2
# 76        1
# 77        1
# 82        1
# Name: NU_IDADE, Length: 65, dtype: int64

# %% [markdown]
# Challenge 1 - which is the proportion between people with 15 years in this*data*
#
# Challenge 2 - whice states is the people with 13 years

# %%
enem['NU_IDADE'].hist();

# %%
#increasing the number of frames in graph, pandas just used 10 in this image, so we need more, for more details
enem['NU_IDADE'].hist(bins = 50, figsize = (10,6));

# %% [markdown]
# Challenge 3 - put a title in graph

# %%
enem.head()
# Out:
#    NU_INSCRICAO  NU_ANO  CO_MUNICIPIO_RESIDENCIA  ... Q023  Q024 Q025
# 0  190001004661    2019                  1506138  ...    A     B    B
# 1  190001004674    2019                  1504208  ...    A     A    B
# 2  190001004722    2019                  1501402  ...    A     A    B
# 3  190001004735    2019                  1507300  ...    A     A    B
# 4  190001004776    2019                  1500800  ...    A     A    B
#
# [5 rows x 136 columns]

# %%
#we will to use the data about "Treineiro" Person , is a person that use the enem how example for try to pass in another type of test like  entrance exam:
#let's do a query() of this column where Treineiro is = 1
#for last , let's just use the treineiro column , for clean the data

enem.query('IN_TREINEIRO == 1' ).head(10)['IN_TREINEIRO']
# Out:
# 0      1
# 4      1
# 12     1
# 14     1
# 16     1
# 27     1
# 37     1
# 88     1
# 90     1
# 133    1
# Name: IN_TREINEIRO, dtype: int64

# %%
#if I want to make a list of the people with 18 years and less 50 years for analysis, I just need to < or > with this code
#query is valid just when we have dataframe

enem.query('NU_IDADE > 17').head(10)
# Out:
#     NU_INSCRICAO  NU_ANO  CO_MUNICIPIO_RESIDENCIA  ... Q023  Q024 Q025
# 1   190001004674    2019                  1504208  ...    A     A    B
# 2   190001004722    2019                  1501402  ...    A     A    B
# 3   190001004735    2019                  1507300  ...    A     A    B
# 5   190001004841    2019                  1503606  ...    A     B    B
# 6   190001004856    2019                  1501402  ...    B     A    B
# 7   190001004904    2019                  1501402  ...    A     A    A
# 9   190001004989    2019                  1506807  ...    A     C    B
# 10  190001005028    2019                  1506807  ...    A     A    A
# 11  190001005057    2019                  1501709  ...    A     A    B
# 13  190001005077    2019                  1501402  ...    A     A    B
#
# [10 rows x 136 columns]

# %%
#this show the age of the most people that are "TREINEIRO" , how expected(15-17 years)
enem.query('IN_TREINEIRO ==1')['NU_IDADE'].value_counts()
# Out:
# 16    7142
# 17    4901
# 15    1927
# 18     858
# 19     228
# 20      83
# 14      64
# 21      44
# 22      30
# 23      21
# 24      13
# 26      13
# 29      10
# 27       9
# 25       8
# 28       6
# 38       4
# 40       4
# 31       4
# 30       4
# 42       4
# 34       3
# 36       2
# 39       2
# 32       2
# 46       2
# 44       2
# 35       2
# 45       1
# 41       1
# 33       1
# 62       1
# 48       1
# 51       1
# 37       1
# 47       1
# 55       1
# Name: NU_IDADE, dtype: int64

# %%
#if I want to organize for age
enem.query('IN_TREINEIRO == 1')['NU_IDADE'].value_counts().sort_index()
# Out:
# 14      64
# 15    1927
# 16    7142
# 17    4901
# 18     858
# 19     228
# 20      83
# 21      44
# 22      30
# 23      21
# 24      13
# 25       8
# 26      13
# 27       9
# 28       6
# 29      10
# 30       4
# 31       4
# 32       2
# 33       1
# 34       3
# 35       2
# 36       2
# 37       1
# 38       4
# 39       2
# 40       4
# 41       1
# 42       4
# 44       2
# 45       1
# 46       2
# 47       1
# 48       1
# 51       1
# 55       1
# 62       1
# Name: NU_IDADE, dtype: int64

# %%
#challenge ... : histogram of age, who is treineiro who is treineiro and not treineiro 
enem['NU_NOTA_REDACAO'].hist(bins = 40 , figsize = (12,7));

# %%
#so much 0 note, let's see languages and codes (linguagens e codigos)
enem['NU_NOTA_LC'].hist(bins = 50, figsize = (12,7));

# %%
#let's compare the min, mean and max of this notes using describe
enem['NU_NOTA_REDACAO'].describe()
# Out:
# count    98043.000000
# mean       571.570025
# std        188.076455
# min          0.000000
# 25%        480.000000
# 50%        580.000000
# 75%        680.000000
# max       1000.000000
# Name: NU_NOTA_REDACAO, dtype: float64

# %%
enem['NU_NOTA_LC'].describe()
# Out:
# count    98043.000000
# mean       520.463928
# std         64.556578
# min          0.000000
# 25%        483.700000
# 50%        526.100000
# 75%        565.100000
# max        801.700000
# Name: NU_NOTA_LC, dtype: float64

# %%
#so now lets make a describe with wholes the notes together
tests =['NU_NOTA_CH', 'NU_NOTA_REDACAO', 'NU_NOTA_CN', 'NU_NOTA_LC', 'NU_NOTA_MT']
enem[tests].describe()
# Out:
#          NU_NOTA_CH  NU_NOTA_REDACAO    NU_NOTA_CN    NU_NOTA_LC    NU_NOTA_MT
# count  98043.000000     98043.000000  92758.000000  98043.000000  92758.000000
# mean     507.365912       571.570025    477.964015    520.463928    523.555206
# std       82.972839       188.076455     76.296099     64.556578    109.416939
# min        0.000000         0.000000      0.000000      0.000000      0.000000
# 25%      447.900000       480.000000    418.000000    483.700000    435.300000
# 50%      510.900000       580.000000    470.200000    526.100000    501.600000
# 75%      567.100000       680.000000    533.300000    565.100000    598.200000
# max      809.400000      1000.000000    797.300000    801.700000    985.000000

# %%
enem[tests].hist(bins = 50, figsize = (16, 10));

# %%
#lets see the median, median is a % of people that have a type of note, for example, let's find the note of 90% of the people

enem['NU_NOTA_REDACAO'].quantile(0.9)
# Out:
# 800.0

# %%
#the result means that 10% of the people had 800 or more of score in test, let's try this for another score
# here we can see 90% of people had 680.8 points and 10% had more than 680.8 points in MT
enem['NU_NOTA_MT'].quantile(0.9)
# Out:
# 680.8

# %%
#let's see the way more clear this median using a boxplot
#the black points in graph mean that score not represent most people, just some cases where some people take a high ou low score in test
#the box in middle of imagem, represent the most score, we can see the variation between 400+ and 600
#the line of the middle of the box, represent the median, the most concetration of scores

enem['NU_NOTA_MT'].plot.box(grid = True, figsize= (7,6));

# %%
enem[tests].boxplot(grid = True, figsize = (10,6));

# %% [markdown]
# ## exploratory analysis

# %%
#lets search and find the state of youngs 13-14 years people that had this test 
enem.query('NU_IDADE <= 14')['SG_UF_RESIDENCIA'].value_counts()
# Out:
# PE    18
# CE    15
# BA    14
# PA    12
# MG    11
# SP    11
# MA     9
# GO     7
# PI     7
# PB     7
# MT     4
# DF     4
# AM     4
# TO     3
# PR     3
# SE     3
# AL     2
# RO     2
# SC     2
# AC     1
# AP     1
# RJ     1
# MS     1
# RS     1
# ES     1
# RN     1
# Name: SG_UF_RESIDENCIA, dtype: int64

# %%
#proportion of participation of each state
enem.query('NU_IDADE <= 14')['SG_UF_RESIDENCIA'].value_counts(normalize = True)
# Out:
# PE    0.124138
# CE    0.103448
# BA    0.096552
# PA    0.082759
# MG    0.075862
# SP    0.075862
# MA    0.062069
# GO    0.048276
# PI    0.048276
# PB    0.048276
# MT    0.027586
# DF    0.027586
# AM    0.027586
# TO    0.020690
# PR    0.020690
# SE    0.020690
# AL    0.013793
# RO    0.013793
# SC    0.013793
# AC    0.006897
# AP    0.006897
# RJ    0.006897
# MS    0.006897
# RS    0.006897
# ES    0.006897
# RN    0.006897
# Name: SG_UF_RESIDENCIA, dtype: float64

# %%
#not recomended to use pie graphics with many pieces, because can be confuse and not worth
less15yo_students = enem.query('NU_IDADE < 15')
less15yo_students['SG_UF_RESIDENCIA'].value_counts().plot.pie(figsize=(9,9));

# %%
#lets use the bar graph, is more easy to visualize 
less15yo_students['SG_UF_RESIDENCIA'].value_counts(normalize = True).plot.bar(figsize = (12, 6));

# %%
#so now let's use the data to know about the target age, or the most people that enter use this test to enter in college (17-20years)
target_age = enem.query('NU_IDADE <= 20')
target_age['SG_UF_RESIDENCIA'].value_counts(normalize = True).plot.bar(figsize = (12,6));

# %%
#you can observe this number represent a trustworthy result of the number os people that make the exame in Brazil per state in this data
#for prove this, we will see in the same graph , people until the oldest age in graph , we will observe not much change.
geral = enem.query('NU_IDADE <= 82') 
geral= enem['SG_UF_RESIDENCIA'].value_counts(normalize = True).plot.bar(title = 'All Ages',  figsize = (12, 6))

# %%
#now let's get the question 6 of score from Nota_LC and use a boxplot to show the results
#Q006 = whice is the your family income ? add  your income with your family and divide per number os members
#we have the A for minor familiy income, and Q for the biggest family income (A-Q)

#We will to use seaborn for boxplot, now we just need to call seaborn with boxplot and tell the x is the question 6 and y is a score of school subject
#the end we just need to put an index and organize the A until Q
#the "data" inside boxplot are from the data where we will to use 

import seaborn as sns
import matplotlib.pyplot as plt

income = enem['Q006'].unique()
income.sort()

plt.figure(figsize=(10,6))  
sns.boxplot(x= 'Q006', y = 'NU_NOTA_MT', data = enem, order= income);
plt.title('Boxplot of MT');

# %%
#in the graph we observed that more lower is the family income, less score they had, the outlayer decrease too(Black points in graph that represent 1.5%)
#now let's see the LC score per income
#Here we see the same thing where the median is higher per family income, but we can oberve the outlayer increasing when we see the lower scores per income family
#It's happened because the same reason of the past graph, this outlayer represent 1.5% of the people that had lower scores, but for lower income family people not have this outlayer, because 24% of the people had the lowest score
plt.figure(figsize=(10,6))  
sns.boxplot(x= 'Q006', y = 'NU_NOTA_LC', data = enem, order= income);
plt.title('Boxplot of LC');

# %%
#now let's sum the scores per line in axis 1
enem[tests].sum(axis = 1)
# Out:
# 0         2288.9
# 1         1184.6
# 2         2350.5
# 3         2555.7
# 4         2803.5
#            ...
# 127375    2867.4
# 127376    2218.5
# 127377    1453.9
# 127378    2573.9
# 127379    2287.8
# Length: 127380, dtype: float64

# %%
#now for add 1 more column with total score called NOTA_TOTAL
enem['NU_NOTA_TOTAL'] = enem[tests].sum(axis = 1)
enem.head(10)
# Out:
#    NU_INSCRICAO  NU_ANO  CO_MUNICIPIO_RESIDENCIA  ... Q024  Q025 NU_NOTA_TOTAL
# 0  190001004661    2019                  1506138  ...    B     B        2288.9
# 1  190001004674    2019                  1504208  ...    A     B        1184.6
# 2  190001004722    2019                  1501402  ...    A     B        2350.5
# 3  190001004735    2019                  1507300  ...    A     B        2555.7
# 4  190001004776    2019                  1500800  ...    A     B        2803.5
# 5  190001004841    2019                  1503606  ...    B     B        3301.4
# 6  190001004856    2019                  1501402  ...    A     B        2599.5
# 7  190001004904    2019                  1501402  ...    A     A        2638.3
# 8  190001004986    2019                  1502400  ...    A     B        3125.1
# 9  190001004989    2019                  1506807  ...    C     B        2794.3
#
# [10 rows x 137 columns]

# %%
#now let's use the boxplot graph using "NOTA_TOTAL" for compare with the family income
plt.figure(figsize=(18,7))
sns.boxplot(x = 'Q006', y = 'NU_NOTA_TOTAL', data = enem, order = income) 
plt.title('TOTAL DE NOTAS');

# %%
#now let's see what is happening, why so many 0, we can see that maybe is something wrong 

sns.displot(enem, x = 'NU_NOTA_TOTAL');

# %%
#the will to use an append in 'NU_NOTA_TOTAL for just return the people that had 0 in enem
#The "NAN" returned in scores can be explained when the person do the test, they put a "NAN" , not a 0.

tests =['NU_NOTA_CH', 'NU_NOTA_REDACAO', 'NU_NOTA_CN', 'NU_NOTA_LC', 'NU_NOTA_MT']
tests.append('NU_NOTA_TOTAL')
enem[tests].query('NU_NOTA_TOTAL == 0')
# Out:
#         NU_NOTA_CH  NU_NOTA_REDACAO  ...  NU_NOTA_MT  NU_NOTA_TOTAL
# 10             NaN              NaN  ...         NaN            0.0
# 11             NaN              NaN  ...         NaN            0.0
# 26             NaN              NaN  ...         NaN            0.0
# 38             NaN              NaN  ...         NaN            0.0
# 40             NaN              NaN  ...         NaN            0.0
# ...            ...              ...  ...         ...            ...
# 127351         NaN              NaN  ...         NaN            0.0
# 127365         NaN              NaN  ...         NaN            0.0
# 127366         NaN              NaN  ...         NaN            0.0
# 127368         NaN              NaN  ...         NaN            0.0
# 127374         NaN              NaN  ...         NaN            0.0
#
# [29162 rows x 6 columns]

# %%
#here we get the people that come at least 1 day in exam
nozero = enem.query('NU_NOTA_TOTAL != 0')
nozero.head()
# Out:
#    NU_INSCRICAO  NU_ANO  CO_MUNICIPIO_RESIDENCIA  ... Q024  Q025 NU_NOTA_TOTAL
# 0  190001004661    2019                  1506138  ...    B     B        2288.9
# 1  190001004674    2019                  1504208  ...    A     B        1184.6
# 2  190001004722    2019                  1501402  ...    A     B        2350.5
# 3  190001004735    2019                  1507300  ...    A     B        2555.7
# 4  190001004776    2019                  1500800  ...    A     B        2803.5
#
# [5 rows x 137 columns]

# %%
plt.figure(figsize=(14,7))
sns.boxplot(x= 'Q006' ,  y = 'NU_NOTA_TOTAL', data = nozero, order = income) 
plt.title('TOTAL DE NOTAS');

# %%
#let's compare with treineiros(orange color)
plt.figure(figsize = (14,7))
sns.boxplot(x ='Q006', y = 'NU_NOTA_TOTAL', hue= "IN_TREINEIRO", order = income, data = nozero)
plt.title('Total de notas comparando com treineiros');

# %% [markdown]
# ## Correlations between notes

# %%
#Now we will plot the notes in a histogram again to see the hist without 0
#in x axis, we can see the score/note of people total, in axis y , you can see the number os people that had this scoreplt.figure(figsize= (12,7))
#kde is a function  that approaches this distribuition 

#Q025 = Whice people have internet -  B true.  Yellow false  (we can use this question to try to explain a little about the difference of scores in test)

plt.figure(figsize=(12,7))
sns.histplot(nozero, x= 'NU_NOTA_TOTAL', kde = True, hue = 'Q025');

# %%
#we can see in this graph, the curve to left, that can indicate people don't have internet home , had less score than people that have internet in home
# now let's make a graph that show the probability 

plt.figure(figsize = (14,7))
sns.histplot(nozero , x = 'NU_NOTA_TOTAL', hue= 'Q025', kde=True, cumulative=True, stat = 'probability');

# %%
#now we will scaterplot to compare 2 scores of 2 differents subject.
plt.figure(figsize= (8,8))
sns.scatterplot(data= nozero, x= 'NU_NOTA_MT', y= 'NU_NOTA_LC');

#let's put a limite in axis x and y using a tuple, because we know that score can go to 0 until 1000
#we use this graph for to compare, the relations between 2 notes

plt.xlim(-50, 1050)
plt.ylim(-50, 1050);

# %%
#we just want the subjects, so we will plot using just the variable tests

sns.pairplot(nozero[tests]);

# %%
#the way numeric to analyse this is using a correlation
#the correlation is a measure that go to -1 until +1 , and 0 +1 
#when the result is near of 0 the correlation is weak between the variables, when near of -1 or +1 the correlation is stronger , when is negative , the proportion is reverse, so 1 variable is positive and another negative
#when correlation is =1 both go up too in a positive proportion 

correlation = nozero[tests].corr()
correlation
# Out:
#                  NU_NOTA_CH  NU_NOTA_REDACAO  ...  NU_NOTA_MT  NU_NOTA_TOTAL
# NU_NOTA_CH         1.000000         0.528338  ...    0.610332       0.735534
# NU_NOTA_REDACAO    0.528338         1.000000  ...    0.493046       0.783647
# NU_NOTA_CN         0.668979         0.504740  ...    0.649527       0.785600
# NU_NOTA_LC         0.744170         0.535797  ...    0.587710       0.711686
# NU_NOTA_MT         0.610332         0.493046  ...    1.000000       0.790051
# NU_NOTA_TOTAL      0.735534         0.783647  ...    0.790051       1.000000
#
# [6 rows x 6 columns]

# %%
#now let's do a heatmap to vizualize this datas
plt.figure(figsize= (10,6))
sns.heatmap(correlation, cmap='cool_r', center = 0, annot=True);
